# %%
# !pip install git+https://github.com/facebookresearch/detectron2
# Out:
# ...
#   Cloning https://github.com/facebookresearch/detectron2 to /tmp/pip-req-build-vb5n5uau
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2 /tmp/pip-req-build-vb5n5uau
#   Resolved https://github.com/facebookresearch/detectron2 to commit eb96ee1d4752ff5896f623f738641fba9c755237
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 20.4 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/gywns6287/BAAM.git
# Out:
# Cloning into 'BAAM'...
# remote: Enumerating objects: 12257, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 12257 (delta 32), reused 89 (delta 0), pack-reused 12112
# Receiving objects: 100% (12257/12257), 108.71 MiB | 39.59 MiB/s, done.
# Resolving deltas: 100% (6852/6852), done.
# Updating files: 100% (8457/8457), done.

# %%
# %cd BAAM
# Out:
# /kaggle/working/BAAM

# %%
# !pip install "git+https://github.com/facebookresearch/pytorch3d.git"
# Out:
# ...
#   Cloning https://github.com/facebookresearch/pytorch3d.git to /tmp/pip-req-build-6kep2g_6
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/pytorch3d.git /tmp/pip-req-build-6kep2g_6
#   Resolved https://github.com/facebookresearch/pytorch3d.git to commit b215776f2d4d31c160538dccdbfe7c827d1d3e88
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pytorch3d: filename=pytorch3d-0.7.6-cp310-cp310-linux_x86_64.whl size=6804161 sha256=9ea014b75e22b441a0cb7cd2682ad14af3e41fd95906ce8d1946959e000a57f1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cndn9_ux/wheels/dd/74/cc/b9266c863f19026f796e59a04e1cd9eb3754474a52ce1b66ce
# Successfully built pytorch3d
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 16.2 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.0.3
#     Uninstalling setuptools-69.0.3:
#       Successfully uninstalled setuptools-69.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# arviz 0.17.1 requires setuptools>=60.0.0, but you have setuptools 59.5.0 which is incompatible.
# conda 23.7.4 requires setuptools>=60.0.0, but you have setuptools 59.5.0 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# ...

# %%
# !pip install gdown

# %%
import gdown

url = 'https://drive.google.com/uc?id=1oM-iA5Z-8AOBgX5hUCfAoLX8hcn4YBpp'

output = 'best_rel_model.pth'

gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1oM-iA5Z-8AOBgX5hUCfAoLX8hcn4YBpp
# From (redirected): https://drive.google.com/uc?id=1oM-iA5Z-8AOBgX5hUCfAoLX8hcn4YBpp&confirm=t&uuid=93e889b7-40ef-4cae-b96e-0ff5cf0e744c
# To: /kaggle/working/BAAM/best_rel_model.pth
# 100%|██████████| 538M/538M [00:04<00:00, 127MB/s]
# 'best_rel_model.pth'

# %%
# !wget https://ad-apolloscape.cdn.bcebos.com/3d_car_instance_sample.tar.gz
# Out:
# --2024-03-27 06:22:40--  https://ad-apolloscape.cdn.bcebos.com/3d_car_instance_sample.tar.gz
# Resolving ad-apolloscape.cdn.bcebos.com (ad-apolloscape.cdn.bcebos.com)... 157.148.65.35
# Connecting to ad-apolloscape.cdn.bcebos.com (ad-apolloscape.cdn.bcebos.com)|157.148.65.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2467906149 (2.3G) [application/x-gzip]
# Saving to: '3d_car_instance_sample.tar.gz'
#
# 3d_car_instance_sam 100%[===================>]   2.30G  11.9MB/s    in 3m 23s
#
# 2024-03-27 06:26:04 (11.6 MB/s) - '3d_car_instance_sample.tar.gz' saved [2467906149/2467906149]

# %%
# !tar -xvzf 3d_car_instance_sample.tar.gz

# %%
import gdown

url = 'https://drive.google.com/uc?id=1ZJdDKwH6aRkgi_idL58TzAEOtjBy3i13'

output = 'data.zip'

gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ZJdDKwH6aRkgi_idL58TzAEOtjBy3i13
# From (redirected): https://drive.google.com/uc?id=1ZJdDKwH6aRkgi_idL58TzAEOtjBy3i13&confirm=t&uuid=65d12e61-4457-417d-a111-685c7eca13c6
# To: /kaggle/working/BAAM/data.zip
# 100%|██████████| 3.73G/3.73G [00:41<00:00, 90.7MB/s]
# 'data.zip'

# %%
# !rm -r apollo

# %%
# !unzip data.zip -d data/

# %%
# !python main.py
# Out:
# Load.... model
# [03/27 06:29:27 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from best_rel_model.pth ...
# Done...
# Loading the dataset
# 100%|█████████████████████████████████████| 731/731 [00:00<00:00, 268785.50it/s]
# Test now begin...
#   0%|                                                   | 0/183 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100%|█████████████████████████████████████████| 183/183 [22:07<00:00,  7.25s/it]

# %%
# !zip -r outputs.zip outputs
